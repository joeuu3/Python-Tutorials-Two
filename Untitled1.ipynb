# %% [markdown]
# ## The Beginning of the Project three

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


proj = pd.read_excel(r"C:\STAFFIDFORPROJECT3Book1.xlsx")
proj
# Out:
#     Unnamed: 0         Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 0          NaN                NaN        NaN         NaN          NaN
# 1          NaN                NaN        NaN         NaN          NaN
# 2          NaN                NaN        NaN         NaN          NaN
# 3          NaN                NaN        NaN         NaN          NaN
# 4          NaN           STAFF ID    SURNAME  FIRST NAME  MIDDLE NAME
# 5          NaN  SID10/NAS/GEY/001      AKPAN       PETER       MONDAY
# 6          NaN  SID10/NAS/GEY/002      AKPAN      SAMUEL      SOLOMON
# 7          NaN  SID10/NAS/GEY/003      AKPAN        OKON        JAMES
# 8          NaN  SID10/NAS/GEY/004      AKPAN         UDO       BASSEY
# 9          NaN  SID10/NAS/GEY/005      AKPAN       UDOMA        MOSES
# 10         NaN  SID10/NAS/GEY/006     BASSEY      BASSEY          UDO
# 11         NaN  SID10/NAS/GEY/007     BASSEY     ANTHONY         EDEM
# ...

# %%
proj.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0         Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 0          NaN                NaN        NaN         NaN          NaN
# 1          NaN                NaN        NaN         NaN          NaN
# 2          NaN                NaN        NaN         NaN          NaN
# 3          NaN                NaN        NaN         NaN          NaN
# 4          NaN           STAFF ID    SURNAME  FIRST NAME  MIDDLE NAME
# 5          NaN  SID10/NAS/GEY/001      AKPAN       PETER       MONDAY
# 6          NaN  SID10/NAS/GEY/002      AKPAN      SAMUEL      SOLOMON
# 7          NaN  SID10/NAS/GEY/003      AKPAN        OKON        JAMES
# 8          NaN  SID10/NAS/GEY/004      AKPAN         UDO       BASSEY
# 9          NaN  SID10/NAS/GEY/005      AKPAN       UDOMA        MOSES
# 10         NaN  SID10/NAS/GEY/006     BASSEY      BASSEY          UDO
# 11         NaN  SID10/NAS/GEY/007     BASSEY     ANTHONY         EDEM
# ...

# %%
seris = pd.read_csv(r"C:\Users\JOSEPH UDOH\Desktop\RAW DATAS\time_series_covid19_confirmed_global.csv")
seris
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  10/25/22  10/26/22  \
# ...
