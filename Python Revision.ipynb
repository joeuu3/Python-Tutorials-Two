# %% [markdown]
# ### This is Python Revision with Jupyter Notebook

# %%
# This is a comment line and would not print
print("This is a Data Analytic Track")

# %%
# Performing calculations in Jupyter

a5 = 56
b6 = 678
c = 5987
d = 4874
add = a5+b6+c # we are adding here
mult = b6 * c # we are multiplying here
divd = (a5 * b6)/c # we are dividing here
sub = d-c # we are subtracting here
print(add)
print(mult)
print(divd)
print(sub)

# %%
# using conc.
conc = a5+b6
str("conc")
print(conc)

# %%
# practice continues

x = 19
y = 43
z = 23
mul = x*y**z
print("The answer is ")
print (mul)
add = x+y-z
print("The answer is ")
print (add)

# %%
Height = 30
Width = 3 * 4
Height/Width
c = Height*Width
print("The Height of the building is ")
print(Height)
print("The Width of the building is ")
print(Width)
print("When the height is multiply by the width, the answer is ")
print(c)

# %%
# Modulus and floor operation in Python
w = 45
p = 57
n = 50
print("The modulus of p and w is ")
print(p%w)
print("The floor between p and w is ")
print(p//w)

# %%
# Comparing Values in two Variables
Value1 = 67
Value2 = 12
result = Value2 == Value2
print(result)

# %%
print("the programs starts here")
Number = input("put any number")
Number = int(number)
if(Number < 13):
    print("the number is less than 13")
else:
    print("the number is not greater than 13")
print("the end of the program")

# %% [markdown]
# ### You are in an aunction, where a car is to be sold. The bid agreed mininum bid for the car is #500000. Write a program that considers FOUR bids and declares the highest bid and announces that the car is sold to that bidder.
#
# NOTE: your code should be able to deal with a tie!

# %% [markdown]
# print (" The heightest number")
# bid = input("enter the amount")
# bid = int(bid):
# if(bid>=500000):
#     print(fail)
# elif(bid>=100000):
#     print(fail)
# elif(bid>= 2000000):
#     print(fail)
# else:
#     (bid>300000000):
#     print(win)
#
# ## To be revisited

# %%
mybirds = ["Parrot", "Sparrow","Crow", "Eagle"]
mybirds.insert(1,'Crow')
mybirds

# %%
myFile = open("NamesAges.txt","r")
print(myFile.read())
# Out:
# Names		Ages
# Kingsley	30
# Ubong		28
# Effiong		32
# Mycella		22
# Inifiok		17
# Imaobong	26
# Ubom		24
# Immanuel	21
# Ekaowo		54
# Henry		21

# %%
import pandas as pd
import numpy as np

# %%
Abuja_Branch = pd.read_csv(r"C:\DAKKADA DATA SET\Abuja_Branch.csv")
Abuja_Branch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1    351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2    529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3    299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4    319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# ..           ...    ...    ...           ...     ...                     ...
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
# ...

# %%
Abuja_Branch.tail(10)
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 322  518-71-6847      B  Abuja        Member    Male      Food and beverages
# 323  156-20-0370      B  Abuja        Normal  Female  Electronic accessories
# 324  151-33-7434      B  Abuja        Normal  Female      Food and beverages
# 325  374-38-5555      B  Abuja        Normal  Female     Fashion accessories
# 326  764-44-8999      B  Abuja        Normal  Female       Health and beauty
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
#      Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# ...

# %%
Lagos_Branch = pd.read_csv(r"C:\DAKKADA DATA SET\Lagos_Branch.csv")
Lagos_Branch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1    631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2    123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3    373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4    355-53-5943      A  Lagos        Member  Female  Electronic accessories
# ..           ...    ...    ...           ...     ...                     ...
# 335  886-18-2897      A  Lagos        Normal  Female      Food and beverages
# 336  745-74-0715      A  Lagos        Normal    Male  Electronic accessories
# 337  727-02-1313      A  Lagos        Member    Male      Food and beverages
# 338  347-56-2442      A  Lagos        Normal    Male      Home and lifestyle
# 339  849-09-3807      A  Lagos        Member  Female     Fashion accessories
#
# ...

# %%
Abuja_Branch.rename(columns = {'Town': 'City'}, inplace=True)
Abuja_Branch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1    351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2    529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3    299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4    319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# ..           ...    ...    ...           ...     ...                     ...
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
# ...

# %%
Abuja_Branch.rename(columns = {'City': 'Town'}, inplace=True)
Abuja_Branch
# Out:
#       Invoice ID Branch   Town Customer type  Gender            Product line  \
# 0    692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1    351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2    529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3    299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4    319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# ..           ...    ...    ...           ...     ...                     ...
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
# ...

# %%
Lagos_Branch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               340 non-null    object
#  1   Branch                   340 non-null    object
#  2   City                     340 non-null    object
#  3   Customer type            340 non-null    object
#  4   Gender                   340 non-null    object
#  5   Product line             340 non-null    object
#  6   Unit price               340 non-null    float64
#  7   Quantity                 340 non-null    int64
#  8   Tax 5%                   340 non-null    float64
#  9   Total                    340 non-null    float64
#  10  Date                     340 non-null    object
#  11  Time                     340 non-null    object
#  12  Payment                  340 non-null    object
#  13  cogs                     340 non-null    float64
# ...

# %%
PH_Branch = pd.read_csv(r"C:\DAKKADA DATA SET\Port_Harcourt_Branch.csv")
PH_Branch
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    226-31-3081      C  Port Harcourt        Normal  Female
# 1    699-14-3026      C  Port Harcourt        Normal    Male
# 2    315-22-5665      C  Port Harcourt        Normal  Female
# 3    300-71-4605      C  Port Harcourt        Member    Male
# 4    183-56-6882      C  Port Harcourt        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0    Electronic accessories      5500.8         5   1375.20   28879.20
# 1    Electronic accessories     30740.4         7  10759.14  225941.94
# ...

# %%
Food_Bev = PH_Branch[PH_Branch["Product line"] == "Food and beverages"]
Food_Bev.head(10)
# Out:
#      Invoice ID Branch           City Customer type  Gender  \
# 4   183-56-6882      C  Port Harcourt        Member  Female
# 8   228-96-1411      C  Port Harcourt        Member  Female
# 11  326-78-5178      C  Port Harcourt        Member    Male
# 18  393-65-2792      C  Port Harcourt        Normal    Male
# 23  829-49-1914      C  Port Harcourt        Member  Female
# 26  480-63-2856      C  Port Harcourt        Normal    Male
# 27  787-56-0757      C  Port Harcourt        Member  Female
# 39  588-01-7461      C  Port Harcourt        Normal  Female
# 47  663-86-9076      C  Port Harcourt        Member  Female
# 53  488-25-4221      C  Port Harcourt        Member  Female
#
#           Product line  Unit price  Quantity    Tax 5%      Total       Date  \
# 4   Food and beverages     35791.2         4   7158.24  150323.04   2/6/2019
# 8   Food and beverages     35532.0         8  14212.80  298468.80   3/4/2019
# ...

# %%
exFile = pd.ExcelFile("Bookshop.xlsx")
books = exFile.parse('Book')
books
# Out:
#    BookID                                              Title AuthID
# 0   BB194                                      Ballinby Boys  AM329
# 1   NC652                                 Nothing But Capers  AS443
# 2   AD222                               Alanna Saves the Day  BH149
# 3   PA169                                         Post Alley  BM856
# 4   TC188                                 Thatchwork Cottage  BM856
# 5   ZT703                                   Zero over Twelve  BM856
# 6   PP866                                        Portmeirion  BT132
# 7   RR774                                           Rystwyth  BT132
# 8   TM925                                  The Mallemaroking  BT132
# 9   CH391                                   Can I Be Honest?  CF829
# 10  NL209                                  No More Lightning  CF829
# 11  NR695                          9803 North Millworks Road  CS190
# 12  TH296                The Winchcombe Railway Museum Heist  CS190
# ...

# %%
Quantity = PH_Branch[PH_Branch"Quantity"] >=7]
Quantity
# Out:
#   Input In [22]
#     Quantity = PH_Branch[PH_Branch"Quantity"] >=7]
#                                   ^
# SyntaxError: invalid syntax

# %%
books.describe
# Out:
# <bound method NDFrame.describe of    BookID                                              Title AuthID
# 0   BB194                                      Ballinby Boys  AM329
# 1   NC652                                 Nothing But Capers  AS443
# 2   AD222                               Alanna Saves the Day  BH149
# 3   PA169                                         Post Alley  BM856
# 4   TC188                                 Thatchwork Cottage  BM856
# 5   ZT703                                   Zero over Twelve  BM856
# 6   PP866                                        Portmeirion  BT132
# 7   RR774                                           Rystwyth  BT132
# 8   TM925                                  The Mallemaroking  BT132
# 9   CH391                                   Can I Be Honest?  CF829
# 10  NL209                                  No More Lightning  CF829
# 11  NR695                          9803 North Millworks Road  CS190
# ...

# %%
books.describe()
# Out:
#        BookID          Title AuthID
# count      58             58     58
# unique     58             58     34
# top     BB194  Ballinby Boys  LD375
# freq        1              1      8

# %%
import matplotlib.pyplot as plt
# Let us define some data points
time = (1.00, 1.23, 2.30, 3.50, 4.45, 5.22)
# Let us define the amount someone makes per this times
moneyMade = (20, 35, 102, 220, 320, 500)
#plotting the wave
plt.plot(time,moneyMade)
